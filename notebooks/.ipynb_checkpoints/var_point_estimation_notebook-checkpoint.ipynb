# %% [markdown]
# # VAR Point Estimation Workflow\nThis notebook demonstrates multivariate VAR(2) point-estimation models (Gaussian, Student-t, Mixture) and rolling evaluation outputs.

# %%
from src.run_var_point_estimation import run_var_point_estimation_workflow

# %%
outputs = run_var_point_estimation_workflow(\n    window_size=500,\n    step_size=5,\n    n_sim=1500,\n    alpha=0.05,\n)\noutputs['comparison']

# %% [markdown]
# The workflow saves structured outputs to `results/<timestamp>/{gaussian,student_t,mixture}/{metrics,figures}`.
